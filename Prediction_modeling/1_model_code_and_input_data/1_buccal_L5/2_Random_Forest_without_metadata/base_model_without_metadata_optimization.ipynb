# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('cleaned_excel_level_5.xlsx')

# %%
print(data.head())
data = data.drop(columns=['sample_ID'])
print("\nMissing values in each column:")
print(data.isnull().sum())
data = data.dropna()

# f and t
X = data.drop(columns=['RFI'])
y = data['RFI']
# Out:
#      sample_ID       RFI  1-14-0-10-45-34  172606-1  2-02-FULL-51-18  \
# 0  Sample_5001 -3.770883              0.0       0.0              0.0
# 1  Sample_5002 -1.942963              0.0       0.0              0.0
# 2  Sample_5003  2.489900              0.0       0.0              0.0
# 3  Sample_5004  2.319945              0.0       0.0              0.0
# 4  Sample_5005  0.396185              0.0       0.0              0.0
#
#    2013-40CM-41-45  20CM-2-55-15  40CM-4-68-19     70-9       A4b  ...  \
# 0              0.0           0.0           0.0  0.00000  0.019297  ...
# 1              0.0           0.0           0.0  0.00000  0.000000  ...
# 2              0.0           0.0           0.0  0.00000  0.000000  ...
# 3              0.0           0.0           0.0  0.00000  0.000000  ...
# 4              0.0           0.0           0.0  0.00645  0.000000  ...
#
#    Xanthobacteraceae_503485  Xanthomonadaceae_616009  Xanthomonadaceae_616012  \
# 0                  0.000000                 0.023156                      0.0
# 1                  0.000000                 0.000000                      0.0
# 2                  0.029888                 0.003321                      0.0
# 3                  0.026546                 0.079639                      0.0
# 4                  0.000000                 0.132220                      0.0
#
#    Xenobiaceae  Xiphinematobacteraceae  Xylanivirgaceae  YIM-B00363  \
# 0          0.0                0.000000              0.0         0.0
# 1          0.0                0.000000              0.0         0.0
# 2          0.0                0.006642              0.0         0.0
# 3          0.0                0.000000              0.0         0.0
# 4          0.0                0.000000              0.0         0.0
#
#    ZCTH02-B6  Zhaonellaceae  other_families
# 0        0.0            0.0        0.617498
# 1        0.0            0.0        0.756656
# 2        0.0            0.0        0.727285
# 3        0.0            0.0        0.845058
# 4        0.0            0.0        1.267374
#
# [5 rows x 649 columns]
#
# Missing values in each column:
# RFI                0
# 1-14-0-10-45-34    0
# 172606-1           0
# 2-02-FULL-51-18    0
# 2013-40CM-41-45    0
#                   ..
# Xylanivirgaceae    0
# YIM-B00363         0
# ZCTH02-B6          0
# Zhaonellaceae      0
# other_families     0
# Length: 648, dtype: int64

# %%
# train 80
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1
)

# %%
# Ibase
rf = RandomForestRegressor(
    n_estimators=100,        
    max_depth=None,          
    min_samples_split=2,     
    min_samples_leaf=1,      
    random_state=1,          
    n_jobs=-1                
)

# %%
#same _base_M
print("\nTraining the Random Forest Regressor...")
rf.fit(X_train, y_train)
# Out:
# Training the Random Forest Regressor...
# RandomForestRegressor(n_jobs=-1, random_state=1)

# %%
# Predict on the test set
y_pred = rf.predict(X_test)

# Calculate evaluation metrics
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"\nRandom Forest Regression -- R^2 Score: {r2:.4f}, RMSE: {rmse:.4f}")
# Out:
# Random Forest Regression -- R^2 Score: 0.4227, RMSE: 2.2529

# %%
importances = rf.feature_importances_
feature_names = X.columns
feature_importances = pd.Series(importances, index=feature_names).sort_values(ascending=False)

# %%
# imp display
print("\nFeature Importances:")
print(feature_importances)
# Out:
# Feature Importances:
# Brevibacillaceae             0.075870
# Moraxellaceae                0.055459
# Domibacillaceae              0.052870
# Caulobacteraceae             0.052170
# Burkholderiaceae_A_580492    0.036451
#                                ...
# UBA1149                      0.000000
# CACZYB01                     0.000000
# UBA11358                     0.000000
# Rhizobiaceae_A_500472        0.000000
# Mal52                        0.000000
# Length: 647, dtype: float64

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x=feature_importances, y=feature_importances.index)
plt.title('Feature Importances from Random Forest')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.tight_layout()
plt.show()
# Out:
# /Users/ugalab4/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ugalab4/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ugalab4/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# only 20
top_features = feature_importances.head(20)

print(top_features)


plt.figure(figsize=(10, 8))
sns.barplot(x=top_features, y=top_features.index)
plt.title('Top 20 Feature Importances from Random Forest')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.tight_layout()
plt.show()
# Out:
# Brevibacillaceae             0.075870
# Moraxellaceae                0.055459
# Domibacillaceae              0.052870
# Caulobacteraceae             0.052170
# Burkholderiaceae_A_580492    0.036451
# Clostridiaceae_222000        0.030108
# Dysgonomonadaceae            0.029752
# Lactobacillaceae             0.021564
# Neisseriaceae_563222         0.017838
# Turicibacteraceae            0.017484
# Bifidobacteriaceae           0.014438
# Enterococcaceae              0.010588
# Erysipelotrichaceae          0.010529
# Aeribacillaceae              0.009578
# Methanobacteriaceae          0.008729
# Metamycoplasmataceae         0.008616
# Xanthomonadaceae_616009      0.008604
# CAG-508                      0.008420
# Weeksellaceae                0.008304
# Peptoniphilaceae             0.008098
# dtype: float64

# %% [markdown]
# # Now going for the base model optimization

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

# Define the parameter distributions to sample from
param_distributions = {
    'n_estimators': randint(50, 1500),          # trees between 50 and 1500
    'max_depth': randint(5, 50),                 #mx dep 5 and 50
    'min_samples_split': randint(2, 20),         #  2 and 20
    'min_samples_leaf': randint(1, 20),          # lowest samples per_leaf bet 1 and 20
    'max_features': ['auto', 'sqrt', 'log2', None],  # lets try the various max_features
    'bootstrap': [True, False],                  # both bo0t and not
}

# %%
##ok now we have parameter array lets random search
rf = RandomForestRegressor(random_state=1, n_jobs=-1)


n_iter_search = 1000  # You can increase this number to try more combinations

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_distributions,
    n_iter=n_iter_search,    
    cv=5,                   
    n_jobs=-1,               
    scoring='r2',
    verbose=2,
    random_state=1,
    return_train_score=True
)

print("\nPerforming randomized search for hyperparameter tuning...")
random_search.fit(X_train, y_train)

best_params = random_search.best_params_
best_rf = random_search.best_estimator_

print(f"\nBest Parameters from Randomized Search: {best_params}")
###########
# Out:
# Performing randomized search for hyperparameter tuning...
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# [CV] END bootstrap=True, max_depth=21, max_features=sqrt, min_samples_leaf=10, min_samples_split=17, n_estimators=1138; total time=   3.4s
# [CV] END bootstrap=False, max_depth=7, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=919; total time=  10.6s
# [CV] END bootstrap=True, max_depth=32, max_features=auto, min_samples_leaf=3, min_samples_split=5, n_estimators=447; total time=   0.0s
# [CV] END bootstrap=True, max_depth=32, max_features=auto, min_samples_leaf=3, min_samples_split=5, n_estimators=447; total time=   0.0s
# [CV] END bootstrap=True, max_depth=32, max_features=auto, min_samples_leaf=3, min_samples_split=5, n_estimators=447; total time=   0.0s
# [CV] END bootstrap=True, max_depth=32, max_features=auto, min_samples_leaf=3, min_samples_split=5, n_estimators=447; total time=   0.0s
# [CV] END bootstrap=True, max_depth=32, max_features=auto, min_samples_leaf=3, min_samples_split=5, n_estimators=447; total time=   0.0s
# [CV] END bootstrap=False, max_depth=41, max_features=auto, min_samples_leaf=9, min_samples_split=3, n_estimators=984; total time=   0.0s
# [CV] END bootstrap=False, max_depth=41, max_features=auto, min_samples_leaf=9, min_samples_split=3, n_estimators=984; total time=   0.0s
# [CV] END bootstrap=False, max_depth=41, max_features=auto, min_samples_leaf=9, min_samples_split=3, n_estimators=984; total time=   0.0s
# [CV] END bootstrap=False, max_depth=41, max_features=auto, min_samples_leaf=9, min_samples_split=3, n_estimators=984; total time=   0.0s
# [CV] END bootstrap=False, max_depth=41, max_features=auto, min_samples_leaf=9, min_samples_split=3, n_estimators=984; total time=   0.0s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=561; total time=   2.6s
# [CV] END bootstrap=True, max_depth=37, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=556; total time=   0.0s
# [CV] END bootstrap=True, max_depth=37, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=556; total time=   0.0s
# [CV] END bootstrap=True, max_depth=17, max_features=log2, min_samples_leaf=6, min_samples_split=18, n_estimators=1006; total time=   2.2s
# [CV] END bootstrap=True, max_depth=34, max_features=None, min_samples_leaf=8, min_samples_split=12, n_estimators=1470; total time=  12.9s
# [CV] END bootstrap=False, max_depth=27, max_features=log2, min_samples_leaf=8, min_samples_split=7, n_estimators=88; total time=   1.0s
# [CV] END bootstrap=False, max_depth=26, max_features=auto, min_samples_leaf=13, min_samples_split=7, n_estimators=812; total time=   0.0s
# [CV] END bootstrap=False, max_depth=26, max_features=auto, min_samples_leaf=13, min_samples_split=7, n_estimators=812; total time=   0.0s
# [CV] END bootstrap=False, max_depth=26, max_features=auto, min_samples_leaf=13, min_samples_split=7, n_estimators=812; total time=   0.0s
# [CV] END bootstrap=False, max_depth=26, max_features=auto, min_samples_leaf=13, min_samples_split=7, n_estimators=812; total time=   0.0s
# [CV] END bootstrap=False, max_depth=26, max_features=auto, min_samples_leaf=13, min_samples_split=7, n_estimators=812; total time=   0.0s
# [CV] END bootstrap=False, max_depth=40, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1355; total time=   0.0s
# [CV] END bootstrap=False, max_depth=40, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1355; total time=   0.0s
# [CV] END bootstrap=False, max_depth=40, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1355; total time=   0.0s
# [CV] END bootstrap=False, max_depth=40, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1355; total time=   0.0s
# [CV] END bootstrap=False, max_depth=40, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=1355; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=13, n_estimators=617; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=13, n_estimators=617; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=13, n_estimators=617; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=13, n_estimators=617; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=10, min_samples_split=13, n_estimators=617; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=9, min_samples_split=8, n_estimators=483; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=9, min_samples_split=8, n_estimators=483; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=9, min_samples_split=8, n_estimators=483; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=9, min_samples_split=8, n_estimators=483; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=9, min_samples_split=8, n_estimators=483; total time=   0.0s
# [CV] END bootstrap=True, max_depth=37, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=1163; total time=   4.6s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=1133; total time=   6.4s
# [CV] END bootstrap=False, max_depth=46, max_features=log2, min_samples_leaf=17, min_samples_split=12, n_estimators=1443; total time=   5.4s
# [CV] END bootstrap=False, max_depth=26, max_features=log2, min_samples_leaf=1, min_samples_split=3, n_estimators=794; total time=   1.8s
# [CV] END bootstrap=False, max_depth=28, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=361; total time=   1.0s
# [CV] END bootstrap=True, max_depth=40, max_features=auto, min_samples_leaf=17, min_samples_split=17, n_estimators=524; total time=   0.0s
# [CV] END bootstrap=True, max_depth=40, max_features=auto, min_samples_leaf=17, min_samples_split=17, n_estimators=524; total time=   0.0s
# [CV] END bootstrap=True, max_depth=40, max_features=auto, min_samples_leaf=17, min_samples_split=17, n_estimators=524; total time=   0.0s
# [CV] END bootstrap=True, max_depth=40, max_features=auto, min_samples_leaf=17, min_samples_split=17, n_estimators=524; total time=   0.0s
# [CV] END bootstrap=True, max_depth=40, max_features=auto, min_samples_leaf=17, min_samples_split=17, n_estimators=524; total time=   0.0s
# [CV] END bootstrap=True, max_depth=28, max_features=sqrt, min_samples_leaf=18, min_samples_split=17, n_estimators=1269; total time=   2.3s
# [CV] END bootstrap=True, max_depth=21, max_features=log2, min_samples_leaf=10, min_samples_split=16, n_estimators=1016; total time=   2.0s
# [CV] END bootstrap=False, max_depth=33, max_features=auto, min_samples_leaf=15, min_samples_split=8, n_estimators=873; total time=   0.0s
# [CV] END bootstrap=True, max_depth=28, max_features=sqrt, min_samples_leaf=12, min_samples_split=14, n_estimators=289; total time=   4.0s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=17, n_estimators=1010; total time=   4.6s
# [CV] END bootstrap=False, max_depth=38, max_features=None, min_samples_leaf=16, min_samples_split=17, n_estimators=528; total time=   8.4s
# [CV] END bootstrap=False, max_depth=16, max_features=sqrt, min_samples_leaf=19, min_samples_split=13, n_estimators=517; total time=   2.9s
# [CV] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=314; total time=   0.0s
# [CV] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=314; total time=   0.0s
# [CV] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=314; total time=   0.0s
# [CV] END bootstrap=False, max_depth=22, max_features=None, min_samples_leaf=15, min_samples_split=2, n_estimators=1428; total time=  17.8s
# [CV] END bootstrap=True, max_depth=35, max_features=None, min_samples_leaf=4, min_samples_split=8, n_estimators=1387; total time=  15.3s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=5, min_samples_split=18, n_estimators=1218; total time=   2.8s
# [CV] END bootstrap=False, max_depth=38, max_features=log2, min_samples_leaf=10, min_samples_split=13, n_estimators=951; total time=   2.0s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=57; total time=   0.0s
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=15, min_samples_split=3, n_estimators=589; total time=   1.3s
# [CV] END bootstrap=False, max_depth=48, max_features=None, min_samples_leaf=16, min_samples_split=9, n_estimators=462; total time=   5.1s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=479; total time=   1.4s
# [CV] END bootstrap=False, max_depth=43, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=1105; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=None, min_samples_leaf=1, min_samples_split=12, n_estimators=978; total time=  11.2s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=13, n_estimators=749; total time=   1.5s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=16, min_samples_split=9, n_estimators=1309; total time=   1.8s
# [CV] END bootstrap=False, max_depth=22, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=846; total time=   1.3s
# [CV] END bootstrap=False, max_depth=30, max_features=None, min_samples_leaf=19, min_samples_split=10, n_estimators=145; total time=   1.6s
# [CV] END bootstrap=True, max_depth=28, max_features=None, min_samples_leaf=9, min_samples_split=12, n_estimators=71; total time=   0.8s
# [CV] END bootstrap=True, max_depth=25, max_features=None, min_samples_leaf=17, min_samples_split=15, n_estimators=92; total time=   0.7s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=600; total time=   0.0s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=600; total time=   0.0s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=600; total time=   0.0s
# [CV] END bootstrap=True, max_depth=38, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=1408; total time=   2.5s
# [CV] END bootstrap=False, max_depth=47, max_features=auto, min_samples_leaf=18, min_samples_split=2, n_estimators=570; total time=   0.0s
# [CV] END bootstrap=False, max_depth=47, max_features=auto, min_samples_leaf=18, min_samples_split=2, n_estimators=570; total time=   0.0s
# [CV] END bootstrap=True, max_depth=25, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=553; total time=   2.2s
# [CV] END bootstrap=True, max_depth=19, max_features=sqrt, min_samples_leaf=7, min_samples_split=18, n_estimators=198; total time=   0.6s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=4, min_samples_split=17, n_estimators=1107; total time=   2.5s
# [CV] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=8, min_samples_split=12, n_estimators=860; total time=   1.9s
# [CV] END bootstrap=False, max_depth=25, max_features=log2, min_samples_leaf=13, min_samples_split=2, n_estimators=147; total time=   0.4s
# [CV] END bootstrap=True, max_depth=36, max_features=log2, min_samples_leaf=16, min_samples_split=11, n_estimators=849; total time=   1.3s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=14, min_samples_split=16, n_estimators=1153; total time=   2.3s
# [CV] END bootstrap=True, max_depth=28, max_features=sqrt, min_samples_leaf=12, min_samples_split=14, n_estimators=289; total time=   0.7s
# [CV] END bootstrap=True, max_depth=28, max_features=log2, min_samples_leaf=2, min_samples_split=16, n_estimators=621; total time=   1.1s
# [CV] END bootstrap=True, max_depth=35, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=1119; total time=   2.2s
# [CV] END bootstrap=False, max_depth=37, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=178; total time=   0.5s
# [CV] END bootstrap=False, max_depth=23, max_features=auto, min_samples_leaf=11, min_samples_split=9, n_estimators=440; total time=   0.0s
# [CV] END bootstrap=False, max_depth=23, max_features=auto, min_samples_leaf=11, min_samples_split=9, n_estimators=440; total time=   0.0s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=1125; total time=   0.0s
# [CV] END bootstrap=False, max_depth=49, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=1055; total time=  15.8s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=7, min_samples_split=17, n_estimators=1333; total time=   2.3s
# [CV] END bootstrap=True, max_depth=27, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=707; total time=   2.1s
# [CV] END bootstrap=False, max_depth=27, max_features=log2, min_samples_leaf=14, min_samples_split=18, n_estimators=656; total time=   1.0s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=12, min_samples_split=15, n_estimators=884; total time=   1.3s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=350; total time=   1.1s
# [CV] END bootstrap=True, max_depth=30, max_features=None, min_samples_leaf=14, min_samples_split=12, n_estimators=1218; total time=   9.8s
# [CV] END bootstrap=False, max_depth=44, max_features=sqrt, min_samples_leaf=7, min_samples_split=13, n_estimators=748; total time=   3.3s
# [CV] END bootstrap=True, max_depth=11, max_features=sqrt, min_samples_leaf=6, min_samples_split=16, n_estimators=582; total time=   1.6s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=369; total time=   0.0s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=369; total time=   0.0s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=369; total time=   0.0s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=369; total time=   0.0s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=369; total time=   0.0s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=678; total time=   1.2s
# [CV] END bootstrap=True, max_depth=44, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=644; total time=   1.3s
# [CV] END bootstrap=False, max_depth=6, max_features=None, min_samples_leaf=2, min_samples_split=19, n_estimators=370; total time=   3.4s
# [CV] END bootstrap=True, max_depth=49, max_features=sqrt, min_samples_leaf=13, min_samples_split=12, n_estimators=1242; total time=   2.5s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=19, min_samples_split=7, n_estimators=1344; total time=   2.6s
# [CV] END bootstrap=False, max_depth=41, max_features=log2, min_samples_leaf=10, min_samples_split=13, n_estimators=469; total time=   1.0s
# [CV] END bootstrap=False, max_depth=40, max_features=log2, min_samples_leaf=9, min_samples_split=8, n_estimators=509; total time=   1.4s
# [CV] END bootstrap=True, max_depth=34, max_features=log2, min_samples_leaf=17, min_samples_split=4, n_estimators=398; total time=   1.6s
# [CV] END bootstrap=False, max_depth=42, max_features=log2, min_samples_leaf=19, min_samples_split=6, n_estimators=1011; total time=   3.2s
# [CV] END bootstrap=True, max_depth=48, max_features=sqrt, min_samples_leaf=15, min_samples_split=7, n_estimators=479; total time=   1.5s
# [CV] END bootstrap=True, max_depth=28, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=363; total time=   1.7s
# [CV] END bootstrap=True, max_depth=33, max_features=None, min_samples_leaf=3, min_samples_split=12, n_estimators=539; total time=   5.9s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=16, min_samples_split=16, n_estimators=494; total time=   1.4s
# [CV] END bootstrap=True, max_depth=27, max_features=log2, min_samples_leaf=10, min_samples_split=12, n_estimators=1400; total time=   4.5s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=561; total time=   2.2s
# [CV] END bootstrap=False, max_depth=38, max_features=log2, min_samples_leaf=10, min_samples_split=13, n_estimators=951; total time=   2.1s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=113; total time=   0.0s
# [CV] END bootstrap=False, max_depth=34, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=846; total time=   2.4s
# [CV] END bootstrap=False, max_depth=29, max_features=log2, min_samples_leaf=1, min_samples_split=18, n_estimators=1427; total time=   4.1s
# [CV] END bootstrap=False, max_depth=43, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=1105; total time=   0.0s
# [CV] END bootstrap=False, max_depth=7, max_features=None, min_samples_leaf=1, min_samples_split=12, n_estimators=978; total time=   9.5s
# [CV] END bootstrap=True, max_depth=26, max_features=None, min_samples_leaf=10, min_samples_split=12, n_estimators=959; total time=   6.4s
# [CV] END bootstrap=False, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1481; total time=   4.2s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=964; total time=   1.9s
# [CV] END bootstrap=True, max_depth=25, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=553; total time=   1.6s
# [CV] END bootstrap=True, max_depth=19, max_features=sqrt, min_samples_leaf=7, min_samples_split=18, n_estimators=198; total time=   0.8s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=4, min_samples_split=17, n_estimators=1107; total time=   2.7s
# [CV] END bootstrap=True, max_depth=36, max_features=auto, min_samples_leaf=19, min_samples_split=9, n_estimators=186; total time=   0.0s
# [CV] END bootstrap=True, max_depth=36, max_features=auto, min_samples_leaf=19, min_samples_split=9, n_estimators=186; total time=   0.0s
# [CV] END bootstrap=True, max_depth=36, max_features=auto, min_samples_leaf=19, min_samples_split=9, n_estimators=186; total time=   0.0s
# [CV] END bootstrap=False, max_depth=28, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=361; total time=   0.9s
# [CV] END bootstrap=True, max_depth=47, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=521; total time=   1.2s
# [CV] END bootstrap=True, max_depth=38, max_features=log2, min_samples_leaf=12, min_samples_split=16, n_estimators=1397; total time=   2.7s
# [CV] END bootstrap=True, max_depth=44, max_features=log2, min_samples_leaf=14, min_samples_split=12, n_estimators=204; total time=   0.5s
# [CV] END bootstrap=True, max_depth=39, max_features=None, min_samples_leaf=11, min_samples_split=17, n_estimators=679; total time=   5.4s
# [CV] END bootstrap=True, max_depth=49, max_features=None, min_samples_leaf=9, min_samples_split=2, n_estimators=1282; total time=  13.2s
# [CV] END bootstrap=True, max_depth=28, max_features=log2, min_samples_leaf=16, min_samples_split=2, n_estimators=1367; total time=   3.0s
# [CV] END bootstrap=False, max_depth=8, max_features=None, min_samples_leaf=13, min_samples_split=19, n_estimators=767; total time=   6.3s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=350; total time=   1.1s
# [CV] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=208; total time=   0.0s
# [CV] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=208; total time=   0.0s
# [CV] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=208; total time=   0.0s
# [CV] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=208; total time=   0.0s
# [CV] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=208; total time=   0.0s
# [CV] END bootstrap=False, max_depth=22, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=208; total time=   0.0s
# [CV] END bootstrap=False, max_depth=22, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=208; total time=   0.0s
# [CV] END bootstrap=False, max_depth=22, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=208; total time=   0.0s
# [CV] END bootstrap=False, max_depth=22, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=208; total time=   0.0s
# [CV] END bootstrap=False, max_depth=31, max_features=None, min_samples_leaf=11, min_samples_split=7, n_estimators=598; total time=   5.7s
# [CV] END bootstrap=True, max_depth=47, max_features=sqrt, min_samples_leaf=12, min_samples_split=14, n_estimators=248; total time=   1.9s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=377; total time=   0.0s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=377; total time=   0.0s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=377; total time=   0.0s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=377; total time=   0.0s
# [CV] END bootstrap=True, max_depth=34, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=377; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=9, min_samples_split=2, n_estimators=914; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=9, min_samples_split=2, n_estimators=914; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=9, min_samples_split=2, n_estimators=914; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=9, min_samples_split=2, n_estimators=914; total time=   0.0s
# [CV] END bootstrap=True, max_depth=6, max_features=auto, min_samples_leaf=9, min_samples_split=2, n_estimators=914; total time=   0.0s
# [CV] END bootstrap=False, max_depth=43, max_features=sqrt, min_samples_leaf=19, min_samples_split=8, n_estimators=1252; total time=   3.0s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=1281; total time=   2.6s
# [CV] END bootstrap=False, max_depth=16, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=1161; total time=   2.0s
# [CV] END bootstrap=False, max_depth=22, max_features=log2, min_samples_leaf=19, min_samples_split=16, n_estimators=727; total time=   3.4s
# [CV] END bootstrap=False, max_depth=40, max_features=auto, min_samples_leaf=18, min_samples_split=5, n_estimators=878; total time=   0.0s
# [CV] END bootstrap=False, max_depth=40, max_features=auto, min_samples_leaf=18, min_samples_split=5, n_estimators=878; total time=   0.0s
# [CV] END bootstrap=False, max_depth=40, max_features=auto, min_samples_leaf=18, min_samples_split=5, n_estimators=878; total time=   0.0s
# [CV] END bootstrap=False, max_depth=40, max_features=auto, min_samples_leaf=18, min_samples_split=5, n_estimators=878; total time=   0.0s
# [CV] END bootstrap=True, max_depth=41, max_features=log2, min_samples_leaf=19, min_samples_split=12, n_estimators=792; total time=   5.6s
# [CV] END bootstrap=False, max_depth=48, max_features=auto, min_samples_leaf=9, min_samples_split=11, n_estimators=765; total time=   0.0s
# [CV] END bootstrap=False, max_depth=25, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=1014; total time=   2.0s
# [CV] END bootstrap=True, max_depth=27, max_features=sqrt, min_samples_leaf=14, min_samples_split=19, n_estimators=676; total time=   3.1s
# [CV] END bootstrap=True, max_depth=23, max_features=None, min_samples_leaf=11, min_samples_split=10, n_estimators=159; total time=   1.9s
# [CV] END bootstrap=False, max_depth=20, max_features=None, min_samples_leaf=18, min_samples_split=2, n_estimators=764; total time=   7.1s
# [CV] END bootstrap=False, max_depth=45, max_features=log2, min_samples_leaf=12, min_samples_split=8, n_estimators=146; total time=   1.2s
# [CV] END bootstrap=False, max_depth=38, max_features=log2, min_samples_leaf=10, min_samples_split=13, n_estimators=951; total time=   2.1s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=16, n_estimators=1433; total time=   2.5s
# [CV] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=14, min_samples_split=12, n_estimators=1183; total time=   2.2s
# [CV] END bootstrap=True, max_depth=12, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=212; total time=   3.0s
# [CV] END bootstrap=True, max_depth=21, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1371; total time=   4.5s
# [CV] END bootstrap=False, max_depth=38, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=978; total time=   0.0s
# [CV] END bootstrap=False, max_depth=38, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=978; total time=   0.0s
# [CV] END bootstrap=False, max_depth=38, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=978; total time=   0.0s
# [CV] END bootstrap=False, max_depth=38, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=978; total time=   0.0s
# [CV] END bootstrap=False, max_depth=38, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=978; total time=   0.0s
# [CV] END bootstrap=False, max_depth=38, max_features=None, min_samples_leaf=2, min_samples_split=16, n_estimators=127; total time=   1.7s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=1186; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=1186; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=1186; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=1186; total time=   0.0s
# [CV] END bootstrap=False, max_depth=6, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=1186; total time=   0.0s
# [CV] END bootstrap=True, max_depth=37, max_features=None, min_samples_leaf=10, min_samples_split=7, n_estimators=1075; total time=   8.8s
# [CV] END bootstrap=False, max_depth=30, max_features=None, min_samples_leaf=19, min_samples_split=10, n_estimators=145; total time=   1.4s
# [CV] END bootstrap=True, max_depth=32, max_features=sqrt, min_samples_leaf=11, min_samples_split=8, n_estimators=443; total time=   1.0s
# [CV] END bootstrap=True, max_depth=33, max_features=log2, min_samples_leaf=9, min_samples_split=2, n_estimators=767; total time=   1.5s
# [CV] END bootstrap=False, max_depth=46, max_features=log2, min_samples_leaf=17, min_samples_split=12, n_estimators=1443; total time=   1.8s
# [CV] END bootstrap=True, max_depth=25, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=553; total time=   1.6s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=19, min_samples_split=8, n_estimators=1279; total time=   2.4s
# [CV] END bootstrap=False, max_depth=26, max_features=log2, min_samples_leaf=1, min_samples_split=3, n_estimators=794; total time=   1.5s
# [CV] END bootstrap=False, max_depth=28, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=361; total time=   1.1s
# [CV] END bootstrap=False, max_depth=25, max_features=log2, min_samples_leaf=13, min_samples_split=2, n_estimators=147; total time=   0.6s
# [CV] END bootstrap=True, max_depth=36, max_features=log2, min_samples_leaf=16, min_samples_split=11, n_estimators=849; total time=   1.4s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=14, min_samples_split=16, n_estimators=1153; total time=   1.9s
# [CV] END bootstrap=True, max_depth=22, max_features=None, min_samples_leaf=2, min_samples_split=15, n_estimators=1479; total time=  14.9s
# [CV] END bootstrap=False, max_depth=38, max_features=None, min_samples_leaf=16, min_samples_split=17, n_estimators=528; total time=   5.7s
# [CV] END bootstrap=True, max_depth=22, max_features=None, min_samples_leaf=2, min_samples_split=16, n_estimators=693; total time=   6.1s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=12, min_samples_split=15, n_estimators=884; total time=   2.3s
# [CV] END bootstrap=False, max_depth=16, max_features=sqrt, min_samples_leaf=9, min_samples_split=4, n_estimators=83; total time=   2.0s
# [CV] END bootstrap=True, max_depth=19, max_features=sqrt, min_samples_leaf=15, min_samples_split=2, n_estimators=1216; total time=   6.6s
# [CV] END bootstrap=True, max_depth=6, max_features=None, min_samples_leaf=17, min_samples_split=15, n_estimators=570; total time=   4.6s
# [CV] END bootstrap=False, max_depth=29, max_features=sqrt, min_samples_leaf=3, min_samples_split=16, n_estimators=749; total time=   2.1s
# [CV] END bootstrap=False, max_depth=6, max_features=None, min_samples_leaf=2, min_samples_split=19, n_estimators=370; total time=   3.7s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=1314; total time=   2.3s
# [CV] END bootstrap=False, max_depth=7, max_features=None, min_samples_leaf=1, min_samples_split=5, n_estimators=276; total time=   3.2s
# [CV] END bootstrap=True, max_depth=13, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=1098; total time=   0.0s
# [CV] END bootstrap=True, max_depth=13, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=1098; total time=   0.0s
# [CV] END bootstrap=True, max_depth=13, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=1098; total time=   0.0s
# [CV] END bootstrap=False, max_depth=40, max_features=log2, min_samples_leaf=9, min_samples_split=8, n_estimators=509; total time=   0.7s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=17, min_samples_split=16, n_estimators=564; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=17, min_samples_split=16, n_estimators=564; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=17, min_samples_split=16, n_estimators=564; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=17, min_samples_split=16, n_estimators=564; total time=   0.0s
# [CV] END bootstrap=True, max_depth=16, max_features=auto, min_samples_leaf=17, min_samples_split=16, n_estimators=564; total time=   0.0s
# [CV] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=1, min_samples_split=3, n_estimators=1293; total time=   0.2s
# [CV] END bootstrap=False, max_depth=22, max_features=None, min_samples_leaf=10, min_samples_split=14, n_estimators=163; total time=   3.3s
# [CV] END bootstrap=False, max_depth=42, max_features=log2, min_samples_leaf=19, min_samples_split=6, n_estimators=1011; total time=   3.0s
# [CV] END bootstrap=False, max_depth=42, max_features=log2, min_samples_leaf=8, min_samples_split=12, n_estimators=261; total time=   0.7s
# [CV] END bootstrap=False, max_depth=18, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=527; total time=   1.6s
# [CV] END bootstrap=False, max_depth=9, max_features=auto, min_samples_leaf=18, min_samples_split=13, n_estimators=1100; total time=   0.0s
# [CV] END bootstrap=False, max_depth=25, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=1014; total time=   2.8s
# [CV] END bootstrap=False, max_depth=25, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=1170; total time=   3.4s
# [CV] END bootstrap=True, max_depth=24, max_features=sqrt, min_samples_leaf=7, min_samples_split=17, n_estimators=1305; total time=   3.9s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=7, min_samples_split=18, n_estimators=1327; total time=   3.4s
# [CV] END bootstrap=True, max_depth=41, max_features=log2, min_samples_leaf=6, min_samples_split=8, n_estimators=784; total time=   2.6s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=113; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=113; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=113; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=113; total time=   0.0s
# [CV] END bootstrap=False, max_depth=34, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=846; total time=   1.6s
# [CV] END bootstrap=True, max_depth=27, max_features=None, min_samples_leaf=6, min_samples_split=3, n_estimators=655; total time=   6.7s
# [CV] END bootstrap=False, max_depth=7, max_features=None, min_samples_leaf=1, min_samples_split=12, n_estimators=978; total time=  10.3s
# [CV] END bootstrap=True, max_depth=27, max_features=sqrt, min_samples_leaf=9, min_samples_split=9, n_estimators=1151; total time=   2.1s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=16, min_samples_split=9, n_estimators=1309; total time=   2.4s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=5, min_samples_split=13, n_estimators=189; total time=   0.7s
# [CV] END bootstrap=False, max_depth=30, max_features=None, min_samples_leaf=19, min_samples_split=10, n_estimators=145; total time=   1.2s
# [CV] END bootstrap=True, max_depth=32, max_features=sqrt, min_samples_leaf=11, min_samples_split=8, n_estimators=443; total time=   1.3s
# [CV] END bootstrap=False, max_depth=34, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=299; total time=   1.0s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=964; total time=   2.0s
# [CV] END bootstrap=True, max_depth=29, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=683; total time=   0.0s
# [CV] END bootstrap=True, max_depth=29, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=683; total time=   0.0s
# [CV] END bootstrap=True, max_depth=29, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=683; total time=   0.0s
# [CV] END bootstrap=True, max_depth=29, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=683; total time=   0.0s
# [CV] END bootstrap=True, max_depth=29, max_features=auto, min_samples_leaf=16, min_samples_split=6, n_estimators=683; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=1462; total time=   2.9s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=940; total time=   2.3s
# [CV] END bootstrap=True, max_depth=47, max_features=auto, min_samples_leaf=17, min_samples_split=17, n_estimators=1354; total time=   0.0s
# [CV] END bootstrap=True, max_depth=47, max_features=auto, min_samples_leaf=17, min_samples_split=17, n_estimators=1354; total time=   0.0s
# [CV] END bootstrap=True, max_depth=47, max_features=auto, min_samples_leaf=17, min_samples_split=17, n_estimators=1354; total time=   0.0s
# [CV] END bootstrap=True, max_depth=47, max_features=auto, min_samples_leaf=17, min_samples_split=17, n_estimators=1354; total time=   0.0s
# [CV] END bootstrap=True, max_depth=47, max_features=auto, min_samples_leaf=17, min_samples_split=17, n_estimators=1354; total time=   0.0s
# [CV] END bootstrap=True, max_depth=47, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=521; total time=   1.1s
# [CV] END bootstrap=True, max_depth=36, max_features=log2, min_samples_leaf=16, min_samples_split=11, n_estimators=849; total time=   1.5s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=14, min_samples_split=16, n_estimators=1153; total time=   2.4s
# [CV] END bootstrap=True, max_depth=23, max_features=log2, min_samples_leaf=14, min_samples_split=3, n_estimators=1382; total time=   2.3s
# [CV] END bootstrap=False, max_depth=22, max_features=sqrt, min_samples_leaf=8, min_samples_split=9, n_estimators=1010; total time=   2.3s
# [CV] END bootstrap=False, max_depth=34, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=69; total time=   0.0s
# [CV] END bootstrap=False, max_depth=34, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=69; total time=   0.0s
# [CV] END bootstrap=False, max_depth=34, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=69; total time=   0.0s
# [CV] END bootstrap=False, max_depth=34, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=69; total time=   0.0s
# [CV] END bootstrap=False, max_depth=34, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=69; total time=   0.0s
# [CV] END bootstrap=False, max_depth=38, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=False, max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=6, n_estimators=1132; total time=  14.3s
# [CV] END bootstrap=True, max_depth=29, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=702; total time=   1.1s
# [CV] END bootstrap=True, max_depth=12, max_features=sqrt, min_samples_leaf=9, min_samples_split=9, n_estimators=942; total time=   1.7s
# [CV] END bootstrap=True, max_depth=25, max_features=None, min_samples_leaf=18, min_samples_split=7, n_estimators=189; total time=   1.9s
# [CV] END bootstrap=False, max_depth=25, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=164; total time=   0.3s
# [CV] END bootstrap=False, max_depth=25, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=164; total time=   0.3s
# [CV] END bootstrap=False, max_depth=22, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=293; total time=   0.5s
# [CV] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=314; total time=   0.0s
# [CV] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=12, min_samples_split=5, n_estimators=314; total time=   0.0s
# [CV] END bootstrap=False, max_depth=22, max_features=None, min_samples_leaf=15, min_samples_split=2, n_estimators=1428; total time=  17.6s
# [CV] END bootstrap=True, max_depth=44, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=644; total time=   2.6s
# [CV] END bootstrap=False, max_depth=40, max_features=None, min_samples_leaf=10, min_samples_split=14, n_estimators=1358; total time=  18.1s
# [CV] END bootstrap=True, max_depth=48, max_features=auto, min_samples_leaf=2, min_samples_split=16, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=48, max_features=auto, min_samples_leaf=2, min_samples_split=16, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=48, max_features=auto, min_samples_leaf=2, min_samples_split=16, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=None, min_samples_leaf=4, min_samples_split=15, n_estimators=954; total time=  12.5s
# [CV] END bootstrap=False, max_depth=13, max_features=auto, min_samples_leaf=14, min_samples_split=17, n_estimators=683; total time=   0.0s
# [CV] END bootstrap=False, max_depth=25, max_features=log2, min_samples_leaf=5, min_samples_split=9, n_estimators=1014; total time=   1.4s
# [CV] END bootstrap=False, max_depth=35, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=180; total time=   0.0s
# [CV] END bootstrap=False, max_depth=35, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=180; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=None, min_samples_leaf=3, min_samples_split=12, n_estimators=539; total time=   5.8s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=16, min_samples_split=16, n_estimators=494; total time=   3.2s
# [CV] END bootstrap=True, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=16, n_estimators=224; total time=   3.9s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=15, min_samples_split=13, n_estimators=844; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=11, min_samples_split=16, n_estimators=423; total time=   1.5s
# [CV] END bootstrap=True, max_depth=43, max_features=log2, min_samples_leaf=17, min_samples_split=19, n_estimators=1304; total time=   1.9s
# [CV] END bootstrap=False, max_depth=32, max_features=sqrt, min_samples_leaf=12, min_samples_split=17, n_estimators=888; total time=   2.3s
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=12, min_samples_split=13, n_estimators=427; total time=   1.7s
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=19, min_samples_split=9, n_estimators=782; total time=   2.1s
# [CV] END bootstrap=True, max_depth=26, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=1392; total time=   3.1s
# [CV] END bootstrap=True, max_depth=38, max_features=None, min_samples_leaf=7, min_samples_split=7, n_estimators=1177; total time=   8.5s
# [CV] END bootstrap=True, max_depth=37, max_features=log2, min_samples_leaf=12, min_samples_split=14, n_estimators=1249; total time=   1.6s
# [CV] END bootstrap=False, max_depth=22, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=846; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=11, min_samples_split=13, n_estimators=59; total time=   0.8s
# [CV] END bootstrap=True, max_depth=32, max_features=sqrt, min_samples_leaf=11, min_samples_split=8, n_estimators=443; total time=   1.1s
# [CV] END bootstrap=False, max_depth=19, max_features=auto, min_samples_leaf=12, min_samples_split=11, n_estimators=604; total time=   0.0s
# [CV] END bootstrap=True, max_depth=25, max_features=None, min_samples_leaf=17, min_samples_split=15, n_estimators=92; total time=   0.8s
# [CV] END bootstrap=False, max_depth=34, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=299; total time=   1.1s
# [CV] END bootstrap=True, max_depth=27, max_features=auto, min_samples_leaf=7, min_samples_split=15, n_estimators=1170; total time=   0.0s
# [CV] END bootstrap=True, max_depth=27, max_features=auto, min_samples_leaf=7, min_samples_split=15, n_estimators=1170; total time=   0.0s
# [CV] END bootstrap=True, max_depth=27, max_features=auto, min_samples_leaf=7, min_samples_split=15, n_estimators=1170; total time=   0.0s
# [CV] END bootstrap=True, max_depth=27, max_features=auto, min_samples_leaf=7, min_samples_split=15, n_estimators=1170; total time=   0.0s
# [CV] END bootstrap=True, max_depth=27, max_features=auto, min_samples_leaf=7, min_samples_split=15, n_estimators=1170; total time=   0.0s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=19, min_samples_split=3, n_estimators=407; total time=   0.5s
# [CV] END bootstrap=False, max_depth=45, max_features=log2, min_samples_leaf=19, min_samples_split=8, n_estimators=365; total time=   0.6s
# [CV] END bootstrap=False, max_depth=43, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=239; total time=   2.9s
# [CV] END bootstrap=False, max_depth=40, max_features=None, min_samples_leaf=7, min_samples_split=2, n_estimators=1124; total time=   9.5s
# [CV] END bootstrap=False, max_depth=22, max_features=auto, min_samples_leaf=2, min_samples_split=13, n_estimators=893; total time=   0.0s
# [CV] END bootstrap=False, max_depth=33, max_features=auto, min_samples_leaf=15, min_samples_split=8, n_estimators=873; total time=   0.0s
# [CV] END bootstrap=False, max_depth=33, max_features=auto, min_samples_leaf=15, min_samples_split=8, n_estimators=873; total time=   0.0s
# [CV] END bootstrap=True, max_depth=39, max_features=None, min_samples_leaf=11, min_samples_split=17, n_estimators=679; total time=   4.7s
# [CV] END bootstrap=False, max_depth=37, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=178; total time=   0.5s
# [CV] END bootstrap=False, max_depth=49, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=1055; total time=  16.1s
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=13, min_samples_split=16, n_estimators=501; total time=   0.9s
# [CV] END bootstrap=True, max_depth=12, max_features=sqrt, min_samples_leaf=9, min_samples_split=9, n_estimators=942; total time=   2.5s
# [CV] END bootstrap=True, max_depth=28, max_features=log2, min_samples_leaf=9, min_samples_split=10, n_estimators=1335; total time=   2.2s
# [CV] END bootstrap=True, max_depth=39, max_features=None, min_samples_leaf=11, min_samples_split=10, n_estimators=765; total time=   8.3s
# [CV] END bootstrap=True, max_depth=47, max_features=sqrt, min_samples_leaf=12, min_samples_split=14, n_estimators=248; total time=   2.1s
# [CV] END bootstrap=False, max_depth=44, max_features=sqrt, min_samples_leaf=7, min_samples_split=13, n_estimators=748; total time=   3.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=7, n_estimators=1186; total time=   2.4s
# [CV] END bootstrap=True, max_depth=31, max_features=log2, min_samples_leaf=3, min_samples_split=11, n_estimators=178; total time=   0.7s
# [CV] END bootstrap=False, max_depth=45, max_features=log2, min_samples_leaf=19, min_samples_split=11, n_estimators=788; total time=   1.4s
# [CV] END bootstrap=False, max_depth=22, max_features=log2, min_samples_leaf=19, min_samples_split=16, n_estimators=727; total time=   1.1s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=11, n_estimators=747; total time=   1.6s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=1, min_samples_split=12, n_estimators=791; total time=   0.0s
# [CV] END bootstrap=False, max_depth=35, max_features=None, min_samples_leaf=15, min_samples_split=12, n_estimators=288; total time=   2.9s
# [CV] END bootstrap=False, max_depth=29, max_features=None, min_samples_leaf=14, min_samples_split=16, n_estimators=1407; total time=  14.3s
# [CV] END bootstrap=True, max_depth=19, max_features=None, min_samples_leaf=4, min_samples_split=15, n_estimators=954; total time=   8.6s
# ...
# [CV] END bootstrap=True, max_depth=24, max_features=None, min_samples_leaf=14, min_samples_split=17, n_estimators=384; total time=   4.6s
# [CV] END bootstrap=True, max_depth=29, max_features=sqrt, min_samples_leaf=16, min_samples_split=8, n_estimators=722; total time=   1.5s
# [CV] END bootstrap=True, max_depth=27, max_features=None, min_samples_leaf=11, min_samples_split=7, n_estimators=1143; total time=   9.4s
# [CV] END bootstrap=False, max_depth=11, max_features=None, min_samples_leaf=19, min_samples_split=12, n_estimators=379; total time=   3.2s
# [CV] END bootstrap=False, max_depth=25, max_features=log2, min_samples_leaf=8, min_samples_split=19, n_estimators=1070; total time=   1.9s
# [CV] END bootstrap=False, max_depth=29, max_features=sqrt, min_samples_leaf=13, min_samples_split=15, n_estimators=937; total time=   2.0s
# [CV] END bootstrap=True, max_depth=27, max_features=log2, min_samples_leaf=14, min_samples_split=10, n_estimators=544; total time=   1.0s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=14, min_samples_split=4, n_estimators=552; total time=   1.6s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=4, min_samples_split=14, n_estimators=472; total time=   0.9s
# [CV] END bootstrap=True, max_depth=8, max_features=None, min_samples_leaf=14, min_samples_split=5, n_estimators=671; total time=   4.4s
# [CV] END bootstrap=True, max_depth=42, max_features=auto, min_samples_leaf=17, min_samples_split=5, n_estimators=441; total time=   0.0s
# [CV] END bootstrap=True, max_depth=42, max_features=auto, min_samples_leaf=17, min_samples_split=5, n_estimators=441; total time=   0.0s
# [CV] END bootstrap=True, max_depth=11, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1168; total time=   3.7s
# [CV] END bootstrap=True, max_depth=26, max_features=sqrt, min_samples_leaf=15, min_samples_split=19, n_estimators=1199; total time=   4.4s
# [CV] END bootstrap=False, max_depth=29, max_features=log2, min_samples_leaf=1, min_samples_split=9, n_estimators=1255; total time=   4.4s
# [CV] END bootstrap=True, max_depth=19, max_features=None, min_samples_leaf=11, min_samples_split=11, n_estimators=1101; total time=  11.9s
# [CV] END bootstrap=True, max_depth=23, max_features=None, min_samples_leaf=3, min_samples_split=8, n_estimators=635; total time=   9.0s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=1387; total time=   6.3s
# [CV] END bootstrap=False, max_depth=11, max_features=None, min_samples_leaf=19, min_samples_split=12, n_estimators=379; total time=   5.8s
# [CV] END bootstrap=False, max_depth=16, max_features=None, min_samples_leaf=11, min_samples_split=5, n_estimators=729; total time=   9.5s
# [CV] END bootstrap=False, max_depth=17, max_features=sqrt, min_samples_leaf=19, min_samples_split=3, n_estimators=555; total time=   1.1s
# [CV] END bootstrap=False, max_depth=24, max_features=None, min_samples_leaf=14, min_samples_split=6, n_estimators=1117; total time=   8.9s
# [CV] END bootstrap=False, max_depth=34, max_features=log2, min_samples_leaf=10, min_samples_split=6, n_estimators=800; total time=   1.6s
# [CV] END bootstrap=False, max_depth=21, max_features=sqrt, min_samples_leaf=8, min_samples_split=11, n_estimators=1067; total time=   2.1s
# [CV] END bootstrap=False, max_depth=9, max_features=None, min_samples_leaf=7, min_samples_split=17, n_estimators=637; total time=   7.2s
# [CV] END bootstrap=True, max_depth=25, max_features=None, min_samples_leaf=13, min_samples_split=13, n_estimators=1252; total time=   9.1s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=4, min_samples_split=14, n_estimators=472; total time=   1.4s
# [CV] END bootstrap=False, max_depth=17, max_features=None, min_samples_leaf=8, min_samples_split=11, n_estimators=514; total time=   4.3s
# [CV] END bootstrap=True, max_depth=21, max_features=None, min_samples_leaf=17, min_samples_split=3, n_estimators=1424; total time=  10.0s
# [CV] END bootstrap=False, max_depth=44, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=1109; total time=   1.8s
# [CV] END bootstrap=False, max_depth=19, max_features=None, min_samples_leaf=16, min_samples_split=10, n_estimators=1495; total time=  14.6s
# [CV] END bootstrap=False, max_depth=32, max_features=sqrt, min_samples_leaf=17, min_samples_split=6, n_estimators=772; total time=   2.8s
# [CV] END bootstrap=True, max_depth=18, max_features=None, min_samples_leaf=14, min_samples_split=4, n_estimators=597; total time=   5.5s
# [CV] END bootstrap=True, max_depth=49, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=838; total time=   0.0s
# [CV] END bootstrap=True, max_depth=49, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=838; total time=   0.0s
# [CV] END bootstrap=True, max_depth=49, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=838; total time=   0.0s
# [CV] END bootstrap=True, max_depth=49, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=838; total time=   0.0s
# [CV] END bootstrap=True, max_depth=49, max_features=auto, min_samples_leaf=1, min_samples_split=7, n_estimators=838; total time=   0.0s
# [CV] END bootstrap=False, max_depth=12, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=740; total time=  10.0s
# [CV] END bootstrap=True, max_depth=23, max_features=None, min_samples_leaf=14, min_samples_split=8, n_estimators=710; total time=   6.9s
# [CV] END bootstrap=True, max_depth=34, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=965; total time=   1.9s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=16, min_samples_split=2, n_estimators=1245; total time=   2.5s
# [CV] END bootstrap=True, max_depth=28, max_features=sqrt, min_samples_leaf=11, min_samples_split=10, n_estimators=289; total time=   1.5s
# [CV] END bootstrap=True, max_depth=15, max_features=None, min_samples_leaf=6, min_samples_split=4, n_estimators=1380; total time=  14.9s
# [CV] END bootstrap=True, max_depth=43, max_features=None, min_samples_leaf=15, min_samples_split=16, n_estimators=1494; total time=  11.8s
# [CV] END bootstrap=False, max_depth=11, max_features=None, min_samples_leaf=13, min_samples_split=5, n_estimators=405; total time=   3.9s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=315; total time=   0.7s
# [CV] END bootstrap=False, max_depth=18, max_features=None, min_samples_leaf=9, min_samples_split=8, n_estimators=578; total time=   6.9s
# [CV] END bootstrap=True, max_depth=37, max_features=None, min_samples_leaf=5, min_samples_split=7, n_estimators=111; total time=   2.2s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=627; total time=   1.0s
# [CV] END bootstrap=False, max_depth=13, max_features=None, min_samples_leaf=15, min_samples_split=4, n_estimators=443; total time=   6.3s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=17, min_samples_split=12, n_estimators=274; total time=   1.6s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=15, min_samples_split=11, n_estimators=1446; total time=   4.7s
# [CV] END bootstrap=True, max_depth=47, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=769; total time=   0.0s
# [CV] END bootstrap=True, max_depth=47, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=769; total time=   0.0s
# [CV] END bootstrap=True, max_depth=47, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=769; total time=   0.0s
# [CV] END bootstrap=True, max_depth=47, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=769; total time=   0.0s
# [CV] END bootstrap=True, max_depth=47, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=769; total time=   0.0s
# [CV] END bootstrap=True, max_depth=49, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=1332; total time=   3.7s
# [CV] END bootstrap=False, max_depth=41, max_features=sqrt, min_samples_leaf=17, min_samples_split=14, n_estimators=696; total time=   1.8s
# [CV] END bootstrap=True, max_depth=48, max_features=None, min_samples_leaf=12, min_samples_split=11, n_estimators=506; total time=   4.5s
# [CV] END bootstrap=False, max_depth=22, max_features=log2, min_samples_leaf=6, min_samples_split=14, n_estimators=905; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=1069; total time=   1.7s
# [CV] END bootstrap=False, max_depth=19, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=1150; total time=   2.4s
# [CV] END bootstrap=True, max_depth=22, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=278; total time=   0.6s
# [CV] END bootstrap=False, max_depth=29, max_features=sqrt, min_samples_leaf=16, min_samples_split=2, n_estimators=750; total time=   1.3s
# [CV] END bootstrap=True, max_depth=23, max_features=log2, min_samples_leaf=8, min_samples_split=9, n_estimators=560; total time=   1.0s
# [CV] END bootstrap=False, max_depth=35, max_features=log2, min_samples_leaf=14, min_samples_split=2, n_estimators=343; total time=   0.9s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=829; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=829; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=829; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=829; total time=   0.0s
# [CV] END bootstrap=False, max_depth=11, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=829; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=1453; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=1453; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=1453; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=8, min_samples_split=8, n_estimators=1453; total time=   0.0s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=13, min_samples_split=2, n_estimators=980; total time=   2.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=10, min_samples_split=13, n_estimators=580; total time=   1.7s
# [CV] END bootstrap=True, max_depth=25, max_features=None, min_samples_leaf=4, min_samples_split=7, n_estimators=1140; total time=  11.5s
# [CV] END bootstrap=False, max_depth=49, max_features=None, min_samples_leaf=3, min_samples_split=16, n_estimators=167; total time=   2.1s
# [CV] END bootstrap=True, max_depth=13, max_features=sqrt, min_samples_leaf=18, min_samples_split=15, n_estimators=1201; total time=   2.9s
# [CV] END bootstrap=False, max_depth=31, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=1093; total time=   3.1s
# [CV] END bootstrap=True, max_depth=25, max_features=None, min_samples_leaf=13, min_samples_split=5, n_estimators=925; total time=   6.5s
# [CV] END bootstrap=False, max_depth=28, max_features=log2, min_samples_leaf=9, min_samples_split=2, n_estimators=640; total time=   1.1s
# [CV] END bootstrap=False, max_depth=26, max_features=sqrt, min_samples_leaf=16, min_samples_split=17, n_estimators=1320; total time=   2.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, min_samples_split=19, n_estimators=593; total time=   1.4s
# [CV] END bootstrap=True, max_depth=27, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=455; total time=   1.2s
# [CV] END bootstrap=True, max_depth=23, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=1269; total time=  14.4s
# [CV] END bootstrap=False, max_depth=11, max_features=log2, min_samples_leaf=19, min_samples_split=9, n_estimators=743; total time=   2.9s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=1461; total time=   5.0s
# [CV] END bootstrap=False, max_depth=12, max_features=None, min_samples_leaf=5, min_samples_split=3, n_estimators=740; total time=  11.6s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=3, n_estimators=1408; total time=   8.2s
# [CV] END bootstrap=False, max_depth=7, max_features=None, min_samples_leaf=4, min_samples_split=12, n_estimators=589; total time=   9.9s
# [CV] END bootstrap=False, max_depth=16, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=225; total time=   4.3s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=18, min_samples_split=13, n_estimators=190; total time=   3.9s
# [CV] END bootstrap=True, max_depth=38, max_features=None, min_samples_leaf=5, min_samples_split=11, n_estimators=596; total time=   9.1s
# [CV] END bootstrap=False, max_depth=43, max_features=sqrt, min_samples_leaf=1, min_samples_split=11, n_estimators=1139; total time=   8.2s
# [CV] END bootstrap=False, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=11, n_estimators=261; total time=   4.0s
# [CV] END bootstrap=False, max_depth=16, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=1278; total time=   3.5s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=1188; total time=   4.2s
# [CV] END bootstrap=True, max_depth=42, max_features=log2, min_samples_leaf=18, min_samples_split=7, n_estimators=1281; total time=   6.0s
# [CV] END bootstrap=False, max_depth=37, max_features=log2, min_samples_leaf=7, min_samples_split=13, n_estimators=1286; total time=   7.1s
# [CV] END bootstrap=False, max_depth=22, max_features=sqrt, min_samples_leaf=9, min_samples_split=11, n_estimators=567; total time=   3.1s
# [CV] END bootstrap=True, max_depth=44, max_features=log2, min_samples_leaf=17, min_samples_split=19, n_estimators=1468; total time=   7.0s
# [CV] END bootstrap=False, max_depth=7, max_features=None, min_samples_leaf=4, min_samples_split=15, n_estimators=1407; total time=  18.3s
# [CV] END bootstrap=False, max_depth=9, max_features=None, min_samples_leaf=9, min_samples_split=18, n_estimators=598; total time=   6.4s
# [CV] END bootstrap=True, max_depth=16, max_features=log2, min_samples_leaf=17, min_samples_split=6, n_estimators=681; total time=   3.3s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=2, min_samples_split=4, n_estimators=1002; total time=   5.8s
# [CV] END bootstrap=True, max_depth=48, max_features=None, min_samples_leaf=12, min_samples_split=15, n_estimators=319; total time=   4.1s
# [CV] END bootstrap=True, max_depth=22, max_features=log2, min_samples_leaf=2, min_samples_split=7, n_estimators=278; total time=   2.2s
# [CV] END bootstrap=False, max_depth=16, max_features=sqrt, min_samples_leaf=15, min_samples_split=13, n_estimators=1196; total time=   5.4s
# [CV] END bootstrap=True, max_depth=17, max_features=log2, min_samples_leaf=1, min_samples_split=14, n_estimators=354; total time=   3.0s
# [CV] END bootstrap=False, max_depth=33, max_features=None, min_samples_leaf=3, min_samples_split=17, n_estimators=248; total time=   8.4s
# [CV] END bootstrap=True, max_depth=13, max_features=sqrt, min_samples_leaf=18, min_samples_split=15, n_estimators=1201; total time=   5.7s
# [CV] END bootstrap=True, max_depth=25, max_features=None, min_samples_leaf=13, min_samples_split=5, n_estimators=925; total time=   7.5s

# %%
#sav outs
results_df = pd.DataFrame(random_search.cv_results_)[['params', 'mean_test_score', 'mean_train_score', 'std_test_score', 'std_train_score']]
results_df['rmse_test_score'] = np.sqrt(1 - results_df['mean_test_score'])  


results_df.to_excel("base_model_without_metadata_optimization.xlsx", index=False)
# Out:
# [CV] END bootstrap=True, max_depth=21, max_features=sqrt, min_samples_leaf=10, min_samples_split=17, n_estimators=1138; total time=   2.6s
# [CV] END bootstrap=False, max_depth=24, max_features=sqrt, min_samples_leaf=18, min_samples_split=16, n_estimators=191; total time=   1.6s
# [CV] END bootstrap=False, max_depth=38, max_features=log2, min_samples_leaf=17, min_samples_split=2, n_estimators=303; total time=   2.2s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=16, min_samples_split=16, n_estimators=494; total time=   2.7s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=19, min_samples_split=16, n_estimators=1111; total time=   3.8s
# [CV] END bootstrap=True, max_depth=32, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=1171; total time=   4.1s
# [CV] END bootstrap=False, max_depth=48, max_features=None, min_samples_leaf=16, min_samples_split=9, n_estimators=462; total time=   8.1s
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=14, min_samples_split=8, n_estimators=421; total time=   3.5s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=11, min_samples_split=13, n_estimators=736; total time=   3.7s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=2, min_samples_split=13, n_estimators=749; total time=   5.3s
# [CV] END bootstrap=True, max_depth=28, max_features=None, min_samples_leaf=9, min_samples_split=12, n_estimators=71; total time=   3.3s
# [CV] END bootstrap=True, max_depth=30, max_features=None, min_samples_leaf=14, min_samples_split=13, n_estimators=988; total time=  10.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=14, n_estimators=578; total time=   4.3s
# [CV] END bootstrap=True, max_depth=45, max_features=log2, min_samples_leaf=15, min_samples_split=10, n_estimators=1136; total time=   9.2s
# [CV] END bootstrap=True, max_depth=28, max_features=log2, min_samples_leaf=16, min_samples_split=2, n_estimators=1367; total time=   5.3s
# [CV] END bootstrap=True, max_depth=28, max_features=log2, min_samples_leaf=9, min_samples_split=10, n_estimators=1335; total time=   3.8s
# [CV] END bootstrap=True, max_depth=30, max_features=None, min_samples_leaf=14, min_samples_split=12, n_estimators=1218; total time=  13.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=13, min_samples_split=7, n_estimators=678; total time=   3.3s
# [CV] END bootstrap=False, max_depth=40, max_features=None, min_samples_leaf=10, min_samples_split=14, n_estimators=1358; total time=  16.2s
# [CV] END bootstrap=True, max_depth=46, max_features=log2, min_samples_leaf=14, min_samples_split=2, n_estimators=704; total time=   3.5s
# [CV] END bootstrap=True, max_depth=19, max_features=sqrt, min_samples_leaf=17, min_samples_split=17, n_estimators=1413; total time=   8.0s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=18, min_samples_split=7, n_estimators=1121; total time=   7.4s
# [CV] END bootstrap=False, max_depth=45, max_features=auto, min_samples_leaf=13, min_samples_split=2, n_estimators=626; total time=   0.0s
# [CV] END bootstrap=False, max_depth=45, max_features=auto, min_samples_leaf=13, min_samples_split=2, n_estimators=626; total time=   0.0s
# [CV] END bootstrap=False, max_depth=45, max_features=auto, min_samples_leaf=13, min_samples_split=2, n_estimators=626; total time=   0.0s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=1029; total time=   4.7s
# [CV] END bootstrap=True, max_depth=43, max_features=log2, min_samples_leaf=14, min_samples_split=13, n_estimators=645; total time=   3.7s
# [CV] END bootstrap=False, max_depth=26, max_features=sqrt, min_samples_leaf=16, min_samples_split=17, n_estimators=1320; total time=   5.8s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=11, min_samples_split=9, n_estimators=1132; total time=   4.8s
# [CV] END bootstrap=True, max_depth=21, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=479; total time=   1.9s
# [CV] END bootstrap=True, max_depth=44, max_features=auto, min_samples_leaf=12, min_samples_split=11, n_estimators=1137; total time=   0.0s
# [CV] END bootstrap=True, max_depth=44, max_features=auto, min_samples_leaf=12, min_samples_split=11, n_estimators=1137; total time=   0.0s
# [CV] END bootstrap=True, max_depth=44, max_features=auto, min_samples_leaf=12, min_samples_split=11, n_estimators=1137; total time=   0.0s
# [CV] END bootstrap=False, max_depth=5, max_features=None, min_samples_leaf=15, min_samples_split=17, n_estimators=1089; total time=  11.7s
# [CV] END bootstrap=True, max_depth=36, max_features=log2, min_samples_leaf=18, min_samples_split=3, n_estimators=805; total time=   2.9s
# [CV] END bootstrap=False, max_depth=42, max_features=log2, min_samples_leaf=14, min_samples_split=15, n_estimators=1243; total time=   7.3s
# [CV] END bootstrap=False, max_depth=41, max_features=sqrt, min_samples_leaf=15, min_samples_split=13, n_estimators=882; total time=   6.0s
# [CV] END bootstrap=False, max_depth=40, max_features=log2, min_samples_leaf=18, min_samples_split=3, n_estimators=251; total time=   3.9s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=4, min_samples_split=14, n_estimators=661; total time=   5.6s
# [CV] END bootstrap=False, max_depth=45, max_features=None, min_samples_leaf=11, min_samples_split=18, n_estimators=266; total time=   6.4s
# [CV] END bootstrap=False, max_depth=13, max_features=sqrt, min_samples_leaf=14, min_samples_split=4, n_estimators=89; total time=   2.8s
# [CV] END bootstrap=False, max_depth=23, max_features=None, min_samples_leaf=5, min_samples_split=15, n_estimators=679; total time=  10.5s
# [CV] END bootstrap=False, max_depth=18, max_features=None, min_samples_leaf=9, min_samples_split=8, n_estimators=578; total time=  11.3s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=676; total time=   3.9s
# [CV] END bootstrap=False, max_depth=32, max_features=None, min_samples_leaf=15, min_samples_split=15, n_estimators=1020; total time=  10.1s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=450; total time=   3.3s
# [CV] END bootstrap=True, max_depth=40, max_features=None, min_samples_leaf=8, min_samples_split=13, n_estimators=888; total time=  10.3s
# [CV] END bootstrap=True, max_depth=36, max_features=log2, min_samples_leaf=15, min_samples_split=11, n_estimators=881; total time=   3.9s
# [CV] END bootstrap=True, max_depth=29, max_features=None, min_samples_leaf=8, min_samples_split=15, n_estimators=1495; total time=  16.8s
# [CV] END bootstrap=False, max_depth=26, max_features=log2, min_samples_leaf=2, min_samples_split=8, n_estimators=333; total time=   3.9s
# [CV] END bootstrap=True, max_depth=25, max_features=None, min_samples_leaf=13, min_samples_split=5, n_estimators=925; total time=   7.7s
# [CV] END bootstrap=False, max_depth=43, max_features=None, min_samples_leaf=14, min_samples_split=8, n_estimators=1284; total time=  17.6s
# [CV] END bootstrap=True, max_depth=26, max_features=sqrt, min_samples_leaf=15, min_samples_split=19, n_estimators=1199; total time=   5.2s
# [CV] END bootstrap=True, max_depth=16, max_features=log2, min_samples_leaf=17, min_samples_split=6, n_estimators=681; total time=   3.4s
# [CV] END bootstrap=True, max_depth=19, max_features=None, min_samples_leaf=11, min_samples_split=11, n_estimators=1101; total time=  10.5s
# [CV] END bootstrap=False, max_depth=17, max_features=sqrt, min_samples_leaf=17, min_samples_split=15, n_estimators=1435; total time=   5.1s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=7, min_samples_split=19, n_estimators=1066; total time=   5.6s
# [CV] END bootstrap=True, max_depth=31, max_features=auto, min_samples_leaf=6, min_samples_split=14, n_estimators=558; total time=   0.0s
# [CV] END bootstrap=True, max_depth=31, max_features=auto, min_samples_leaf=6, min_samples_split=14, n_estimators=558; total time=   0.0s
# [CV] END bootstrap=True, max_depth=31, max_features=auto, min_samples_leaf=6, min_samples_split=14, n_estimators=558; total time=   0.0s
# [CV] END bootstrap=True, max_depth=31, max_features=auto, min_samples_leaf=6, min_samples_split=14, n_estimators=558; total time=   0.0s
# [CV] END bootstrap=True, max_depth=31, max_features=auto, min_samples_leaf=6, min_samples_split=14, n_estimators=558; total time=   0.0s
# [CV] END bootstrap=False, max_depth=21, max_features=sqrt, min_samples_leaf=8, min_samples_split=11, n_estimators=1067; total time=   5.6s
# [CV] END bootstrap=False, max_depth=49, max_features=sqrt, min_samples_leaf=10, min_samples_split=7, n_estimators=401; total time=   4.6s
# [CV] END bootstrap=False, max_depth=36, max_features=log2, min_samples_leaf=12, min_samples_split=17, n_estimators=1055; total time=   5.0s
# [CV] END bootstrap=True, max_depth=8, max_features=None, min_samples_leaf=14, min_samples_split=5, n_estimators=671; total time=   5.8s
# [CV] END bootstrap=False, max_depth=20, max_features=auto, min_samples_leaf=17, min_samples_split=3, n_estimators=799; total time=   0.0s
# [CV] END bootstrap=True, max_depth=37, max_features=auto, min_samples_leaf=2, min_samples_split=19, n_estimators=946; total time=   0.0s
# [CV] END bootstrap=True, max_depth=37, max_features=auto, min_samples_leaf=2, min_samples_split=19, n_estimators=946; total time=   0.0s
# [CV] END bootstrap=True, max_depth=37, max_features=auto, min_samples_leaf=2, min_samples_split=19, n_estimators=946; total time=   0.0s
# [CV] END bootstrap=True, max_depth=37, max_features=auto, min_samples_leaf=2, min_samples_split=19, n_estimators=946; total time=   0.0s
# [CV] END bootstrap=True, max_depth=37, max_features=auto, min_samples_leaf=2, min_samples_split=19, n_estimators=946; total time=   0.0s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=7, min_samples_split=4, n_estimators=199; total time=   2.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=18, min_samples_split=12, n_estimators=70; total time=   1.7s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=999; total time=   4.9s
# [CV] END bootstrap=True, max_depth=27, max_features=log2, min_samples_leaf=10, min_samples_split=12, n_estimators=1400; total time=   5.1s
# [CV] END bootstrap=False, max_depth=45, max_features=log2, min_samples_leaf=12, min_samples_split=8, n_estimators=146; total time=   1.4s
# [CV] END bootstrap=False, max_depth=49, max_features=None, min_samples_leaf=12, min_samples_split=5, n_estimators=1374; total time=  15.7s
# [CV] END bootstrap=False, max_depth=38, max_features=None, min_samples_leaf=2, min_samples_split=16, n_estimators=127; total time=   4.3s
# [CV] END bootstrap=True, max_depth=15, max_features=None, min_samples_leaf=6, min_samples_split=5, n_estimators=1105; total time=  13.4s
# [CV] END bootstrap=False, max_depth=41, max_features=sqrt, min_samples_leaf=10, min_samples_split=17, n_estimators=96; total time=   5.5s
# [CV] END bootstrap=True, max_depth=22, max_features=None, min_samples_leaf=2, min_samples_split=15, n_estimators=1479; total time=  20.2s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=12, min_samples_split=11, n_estimators=1393; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=12, min_samples_split=11, n_estimators=1393; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=12, min_samples_split=11, n_estimators=1393; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=12, min_samples_split=11, n_estimators=1393; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=12, min_samples_split=11, n_estimators=1393; total time=   0.0s
# [CV] END bootstrap=True, max_depth=22, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=711; total time=   4.6s
# [CV] END bootstrap=False, max_depth=22, max_features=log2, min_samples_leaf=3, min_samples_split=5, n_estimators=293; total time=   2.5s
# [CV] END bootstrap=True, max_depth=30, max_features=None, min_samples_leaf=14, min_samples_split=12, n_estimators=1218; total time=  13.5s
# [CV] END bootstrap=False, max_depth=29, max_features=sqrt, min_samples_leaf=3, min_samples_split=16, n_estimators=749; total time=   3.7s
# [CV] END bootstrap=False, max_depth=28, max_features=sqrt, min_samples_leaf=15, min_samples_split=9, n_estimators=377; total time=   3.8s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, min_samples_split=9, n_estimators=267; total time=   3.9s
# [CV] END bootstrap=False, max_depth=29, max_features=None, min_samples_leaf=10, min_samples_split=4, n_estimators=868; total time=  15.6s
# [CV] END bootstrap=False, max_depth=23, max_features=log2, min_samples_leaf=16, min_samples_split=8, n_estimators=733; total time=   4.6s
# [CV] END bootstrap=False, max_depth=25, max_features=None, min_samples_leaf=7, min_samples_split=19, n_estimators=771; total time=  12.6s
# [CV] END bootstrap=True, max_depth=44, max_features=None, min_samples_leaf=3, min_samples_split=5, n_estimators=498; total time=   7.6s
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=10, min_samples_split=6, n_estimators=1338; total time=   5.2s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=13, min_samples_split=9, n_estimators=528; total time=   2.4s
# [CV] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=17, n_estimators=900; total time=   3.3s
# [CV] END bootstrap=False, max_depth=32, max_features=sqrt, min_samples_leaf=17, min_samples_split=6, n_estimators=772; total time=   3.6s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=7, min_samples_split=5, n_estimators=1461; total time=   6.0s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=1099; total time=   7.5s
# [CV] END bootstrap=False, max_depth=8, max_features=None, min_samples_leaf=12, min_samples_split=14, n_estimators=990; total time=  13.8s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=763; total time=   6.8s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=7, min_samples_split=15, n_estimators=1486; total time=   7.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=9, min_samples_split=5, n_estimators=1327; total time=   6.3s
# [CV] END bootstrap=False, max_depth=41, max_features=sqrt, min_samples_leaf=9, min_samples_split=15, n_estimators=114; total time=   2.9s
# [CV] END bootstrap=False, max_depth=43, max_features=None, min_samples_leaf=14, min_samples_split=8, n_estimators=1284; total time=  19.4s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=1188; total time=   4.9s
# [CV] END bootstrap=True, max_depth=42, max_features=log2, min_samples_leaf=18, min_samples_split=7, n_estimators=1281; total time=   5.1s
# [CV] END bootstrap=False, max_depth=47, max_features=None, min_samples_leaf=10, min_samples_split=16, n_estimators=496; total time=   7.4s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=16, min_samples_split=19, n_estimators=570; total time=   3.0s
# [CV] END bootstrap=True, max_depth=31, max_features=None, min_samples_leaf=15, min_samples_split=6, n_estimators=182; total time=   3.7s
# [CV] END bootstrap=True, max_depth=29, max_features=None, min_samples_leaf=8, min_samples_split=15, n_estimators=1495; total time=  17.0s
# [CV] END bootstrap=False, max_depth=26, max_features=log2, min_samples_leaf=2, min_samples_split=8, n_estimators=333; total time=   3.6s
# [CV] END bootstrap=True, max_depth=25, max_features=None, min_samples_leaf=13, min_samples_split=5, n_estimators=925; total time=   7.6s
# [CV] END bootstrap=True, max_depth=21, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=417; total time=   4.1s
# [CV] END bootstrap=False, max_depth=23, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=889; total time=   0.0s
# [CV] END bootstrap=False, max_depth=23, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=889; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=9, min_samples_split=14, n_estimators=876; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=9, min_samples_split=14, n_estimators=876; total time=   0.0s
# [CV] END bootstrap=True, max_depth=36, max_features=auto, min_samples_leaf=11, min_samples_split=16, n_estimators=122; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=None, min_samples_leaf=4, min_samples_split=3, n_estimators=131; total time=   4.6s
# [CV] END bootstrap=True, max_depth=8, max_features=None, min_samples_leaf=14, min_samples_split=5, n_estimators=671; total time=   6.3s
# [CV] END bootstrap=True, max_depth=24, max_features=auto, min_samples_leaf=19, min_samples_split=8, n_estimators=1214; total time=   0.0s
# [CV] END bootstrap=False, max_depth=23, max_features=None, min_samples_leaf=14, min_samples_split=14, n_estimators=334; total time=   7.2s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=17, min_samples_split=9, n_estimators=627; total time=   5.3s
# [CV] END bootstrap=False, max_depth=39, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=1144; total time=   0.0s
# [CV] END bootstrap=False, max_depth=39, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=1144; total time=   0.0s
# [CV] END bootstrap=False, max_depth=39, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=1144; total time=   0.0s
# [CV] END bootstrap=False, max_depth=39, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=1144; total time=   0.0s
# [CV] END bootstrap=False, max_depth=39, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=1144; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=9, min_samples_split=4, n_estimators=1133; total time=   0.0s
# [CV] END bootstrap=True, max_depth=33, max_features=auto, min_samples_leaf=9, min_samples_split=4, n_estimators=1133; total time=   0.0s
# [CV] END bootstrap=True, max_depth=19, max_features=auto, min_samples_leaf=16, min_samples_split=14, n_estimators=1416; total time=   0.0s
# [CV] END bootstrap=False, max_depth=26, max_features=sqrt, min_samples_leaf=15, min_samples_split=4, n_estimators=571; total time=   2.6s
# [CV] END bootstrap=True, max_depth=30, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=1201; total time=  12.8s
# [CV] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=11, min_samples_split=17, n_estimators=345; total time=   5.2s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=10, min_samples_split=8, n_estimators=1315; total time=   4.3s
# [CV] END bootstrap=True, max_depth=44, max_features=log2, min_samples_leaf=17, min_samples_split=19, n_estimators=1468; total time=   7.7s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=1387; total time=   7.2s
# [CV] END bootstrap=True, max_depth=21, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=417; total time=   4.8s
# [CV] END bootstrap=False, max_depth=31, max_features=sqrt, min_samples_leaf=8, min_samples_split=14, n_estimators=1093; total time=   4.7s
# [CV] END bootstrap=False, max_depth=17, max_features=None, min_samples_leaf=8, min_samples_split=11, n_estimators=514; total time=   5.6s
# [CV] END bootstrap=False, max_depth=8, max_features=None, min_samples_leaf=19, min_samples_split=7, n_estimators=1115; total time=  15.3s
# [CV] END bootstrap=True, max_depth=45, max_features=None, min_samples_leaf=6, min_samples_split=8, n_estimators=1318; total time=  18.0s
# [CV] END bootstrap=True, max_depth=43, max_features=None, min_samples_leaf=15, min_samples_split=16, n_estimators=1494; total time=  16.9s
# [CV] END bootstrap=False, max_depth=23, max_features=None, min_samples_leaf=14, min_samples_split=14, n_estimators=334; total time=  10.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=676; total time=   3.9s
# [CV] END bootstrap=False, max_depth=39, max_features=None, min_samples_leaf=7, min_samples_split=19, n_estimators=585; total time=   8.3s
# [CV] END bootstrap=False, max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=486; total time=   3.7s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=3, min_samples_split=11, n_estimators=1373; total time=   7.2s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=16, min_samples_split=19, n_estimators=570; total time=   2.9s
# [CV] END bootstrap=False, max_depth=24, max_features=None, min_samples_leaf=14, min_samples_split=6, n_estimators=1117; total time=  14.2s
# [CV] END bootstrap=False, max_depth=49, max_features=sqrt, min_samples_leaf=10, min_samples_split=7, n_estimators=401; total time=   5.7s
# [CV] END bootstrap=False, max_depth=21, max_features=sqrt, min_samples_leaf=18, min_samples_split=5, n_estimators=1387; total time=   5.9s
# [CV] END bootstrap=False, max_depth=17, max_features=None, min_samples_leaf=8, min_samples_split=11, n_estimators=514; total time=   5.7s

# %%
y_pred_best = best_rf.predict(X_test)

# Calculate evaluation metrics
r2_best = r2_score(y_test, y_pred_best)
rmse_best = np.sqrt(mean_squared_error(y_test, y_pred_best))

print(f"\nRandom Forest Regression (Best Estimator) -- R^2 Score: {r2_best:.4f}, RMSE: {rmse_best:.4f}")
#####
# Out:
# Random Forest Regression (Best Estimator) -- R^2 Score: 0.3941, RMSE: 2.3079

# %%
from mpl_toolkits.mplot3d import Axes3D

def plot_3d_param_performance(param_x, param_y):
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    x = results['param_' + param_x]
    y = results['param_' + param_y]
    z = results['mean_test_score']
    img = ax.scatter(x, y, z, c=z, cmap='viridis')
    ax.set_xlabel(param_x)
    ax.set_ylabel(param_y)
    ax.set_zlabel('Mean R² Score')
    fig.colorbar(img)
    plt.title(f'3D Plot of {param_x} vs {param_y} vs Mean R² Score')
    plt.show()

# Example 3D plots
plot_3d_param_performance('max_depth', 'min_samples_split')

# %%
# imp feat
importances_best = best_rf.feature_importances_
feature_importances_best = pd.Series(importances_best, index=feature_names).sort_values(ascending=False)


print(feature_importances_best)

# 20
top_features_best = feature_importances_best.head(20)

plt.figure(figsize=(10, 8))
sns.barplot(x=top_features_best, y=top_features_best.index)
plt.title('Top 20 Feature Importances from Best Random Forest Model')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.tight_layout()
plt.show()
# Out:
# Burkholderiaceae_A_580492    0.024801
# Caulobacteraceae             0.024302
# Dysgonomonadaceae            0.023446
# Domibacillaceae              0.021184
# Brevibacillaceae             0.020116
#                                ...
# Reconcilibacillaceae         0.000000
# Quadrisphaeraceae            0.000000
# Ferrovibrionaceae            0.000000
# QAMH01                       0.000000
# 1-14-0-10-45-34              0.000000
# Length: 647, dtype: float64

# %%
from mpl_toolkits.mplot3d import Axes3D

def plot_3d_param_performance_surface(param_x, param_y):
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    
   
    x = results['param_' + param_x]
    y = results['param_' + param_y]
    z = results['mean_test_score']
    
    
    surf = ax.plot_trisurf(x, y, z, cmap='viridis', edgecolor='none')
    
   
    ax.set_xlabel(param_x)
    ax.set_ylabel(param_y)
    ax.set_zlabel('Mean R² Score')
    
    
    fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)
    
   
    plt.title(f'3D Surface Plot of {param_x} vs {param_y} vs Mean R² Score')
    
    plt.show()


plot_3d_param_performance_surface('max_depth', 'min_samples_split')
# Out:
# /apps/eb/Anaconda3/2023.09-0/lib/python3.11/site-packages/pandas/core/series.py:917: RuntimeWarning: invalid value encountered in cast
#   arr = np.asarray(values, dtype=dtype)

# %%
plot_3d_param_performance_surface('n_estimators', 'max_depth')
